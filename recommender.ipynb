# %%
import pandas as pd
import numpy as np
import re

df = pd.read_csv('staff.am_data_2020.csv')

# %%
def clean_str(s, condense=False):
    if isinstance(s, str):
        s = re.sub('[^0-9a-zA-Z]+', ' ', s)
        if condense:
            s = ''.join(s.split())
        else:
            s = ' '.join(s.split())
        s = s.lower()
        return s
    return clean_str(str(s))

def condense_str(s):
    return clean_str(s, True)

def to_list(csl):
    if isinstance(csl, str):
        words = csl.split(',')
        return [condensed_str(word) for word in words]
    elif isinstance(csl, list):
        return csl
    return ''

# Clean strings
df['title'] = df['title'].apply(condense_str)
df['employment_terms'] = df['employment_terms'].apply(condense_str)
df['job_type'] = df['job_type'].apply(condense_str)
df['category'] = df['category'].apply(condense_str)
df['required_qualifications'] = df['required_qualifications'].apply(clean_str)
df['responsibilities'] = df['responsibilities'].apply(clean_str)
df['candidate_level'] = df['candidate_level'].apply(condense_str)

# Convert comma-separated lists into Python lists
df['soft_skills'] = df['soft_skills'].apply(to_list)
df['prof_skills'] = df['prof_skills'].apply(to_list)

# Convert to date
df['deadline'] = df['deadline'].apply(lambda x: pd.to_datetime(x, format='%Y-%m-%d', errors='ignore'))

# %%
df.head(10)
# Out:
#                           id                          title employment_terms  \
# 0      YB5jCG9jORj5PDq5DQOK3                salesconsultant        permanent
# 1      Bt7vbu3oBdF6fNH5SvIm3                 managerhostess        permanent
# 2      oH7bOT6HPYs4xnr7JOQL4            marketingspecialist        permanent
# 3      zK7cxx6TSIV4lLp9sFba8             projectcoordinator        permanent
# 4      yg7GdF9DMxQ0YuO0bcOZ6  networkandsystemadministrator        permanent
# 5  Hs1rHE1aFSn5awY0Nujv6hEW7                        sfasdfa        permanent
# 6  sw1WyC2deDc2Qsb9hZCS0Rbj6         iosandandroiddeveloper        permanent
# 7  hh1PkS3HjoI4KhT0XPCO8psb3                                       permanent
# 8  Zi1VzG4lDLH7qYH6wVsa5xnP3                          sdffe        permanent
# 9  FO1lSO5ZBtg3wdA3OnZQ3UUJ7            digitalproductowner        permanent
#
#    job_type   deadline                  category  \
# 0  fulltime 2020-04-09    salesservicemanagement
# 1  fulltime 2020-08-26  tourismhospitalityhoreca
# 2  fulltime 2020-08-31      marketingadvertising
# 3  fulltime 2020-08-31  productprojectmanagement
# 4  fulltime 2020-09-06                   otherit
# 5  fulltime 2020-08-26       softwaredevelopment
# 6  fulltime 2020-07-31       softwaredevelopment
# 7  fulltime 2020-08-28     networkadministration
# 8  fulltime 2020-08-18   qualityassurancecontrol
# 9  fulltime 2020-02-10                   otherit
#
#                              required_qualifications  \
# 0                                                nan
# 1  female higher education in linguistics economi...
# 2                                                nan
# 3                                                nan
# 4  higher technical nbsp education at least 2 yea...
# 5                                                nan
# 6  experience in developing native ios app s avai...
# 7  proven experience as a system administrator ne...
# 8                                                nan
# 9  bachelor rsquo s degree in computer science bu...
#
#                                     responsibilities  \
# 0                                                nan
# 1  manage the daily operations ensure that all st...
# 2                                                nan
# 3                                                nan
# 4  configures and maintains microsoft active dire...
# 5                                                nan
# 6                                                nan
# 7  manage network servers and technology tools se...
# 8                                                nan
# 9  take the lead of a scrum team as a technical p...
#
#                                          soft_skills  \
# 0  [positiveattitude, customerserviceoriented, fl...
# 1
# 2
# 3
# 4  [abilitytoworkindependently, problemsolving, t...
# 5                                   [artisticskills]
# 6
# 7    [teamwork, senseofresponsibility, enterprising]
# 8
# 9      [analyticalskills, teamwork, productoriented]
#
#                               prof_skills salary candidate_level
# 0                [salesserviceexperience]    NaN          junior
# 1              [english, russianlanguage]    NaN        midlevel
# 2                            [initiative]    NaN          senior
# 3                              [b2bsales]    NaN          senior
# 4       [linuxos, tcpip, activedirectory]    NaN        midlevel
# 5                                            NaN          junior
# 6  [androidndk, iossdk, java, androidsdk]    NaN      notdefined
# 7                                            NaN          senior
# 8                      [phpzendframework]    NaN          junior
# 9                                            NaN      notdefined

# %%
def rep(s, t=100):
    return (s + ' ') * t

def create_soup(x):
    classes = rep(x['title']) + rep(x['employment_terms'], 1) + rep(x['job_type'], 1) + rep(x['category']) + rep(x['candidate_level'])
    description = x['required_qualifications'] + ' ' + x['responsibilities'] + ' ' + ' '.join(x['soft_skills']) + ' ' + ' '.join(x['prof_skills'])
    return classes + description

df['soup'] = df.apply(create_soup, axis=1)

df.iloc[0]['soup']
# Out:
# 'salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant salesconsultant permanent fulltime salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement salesservicemanagement junior junior junior junior junior junior junior junior junior junior junior jun ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_mat = count.fit_transform(df['soup'])

count_mat.shape
# Out:
# (6422, 13630)

# %%
test_job = {
    'id': 'test_job',
    'title': condense_str('Marketing Specialist'),
    'employment_terms': condense_str('Permanent'),
    'job_type': condense_str('Full time'),
    'deadline': condense_str('2020-12-31'),
    'category': condense_str('Marketing/Advertising'),
    'required_qualifications': clean_str("""Education background does not matter; we are looking for talent, experience, passion and creativity.
        At least 1 year of professional full-time experience in social media marketing is preferred.
        Experience with running social media pages such as Facebook is a must, experience with Linkedin, Insta and YouTube is a plus.
        Excellent in creative content writing, 
        Experience and knowledge of Adobe Photoshop (knowledge of other tools is a plus), for creating social media postings, based on visual templates provided by the designer.
        Strong written and verbal communication in Armenian and English languages, Russian is desirable.
        Positive attitude, detail and customer oriented with good multitasking and organisational ability."""),
    'responsibilities': clean_str("""Develop original and exciting SMM campaigns and content on a daily basis (e.g. social media posts, website content, etc).
        Coordinate with marketing and design teams to generate relevant marketing content, 
        Manage staff.am's & HireBee's social media presence on Facebook, Linkedin, Telegram, Instagram and YouTube.
        Prepare successful email marketing campaigns with well-structured content.
        Maintain appropriate tone of voice through social media and other digital channels.
        Suggest and implement other marketing activities to boost awareness and increase website traffic and app installs.
        Complete other tasks related to Marketing as required."""),
    'soft_skills': to_list('Written communication skills,Positive attitude,Time management,Team player'),
    'prof_skills': to_list('Adobe Photoshop,SMM,Email Marketing,Content marketing'),
    'salary': condense_str('NaN'),
    'candidate_level': condense_str('Mid level')
}

test_job['soup'] = create_soup(test_job)
test_job['soup']
# Out:
# 'marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist marketingspecialist permanent fulltime marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising marketingadvertising market ...

# %%
count2 = CountVectorizer(vocabulary=count.vocabulary_.keys())
count2_mat = count2.fit_transform([test_job['soup']])

count2_mat.shape
# Out:
# (1, 13630)

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(count_mat, count2_mat)
df = df.reset_index(drop=True)
indices = pd.Series(df.index, index=df['id'])

cosine_sim.shape
# Out:
# (6422, 1)

# %%
sim_scores = list(enumerate(np.squeeze(np.asarray(cosine_sim))))
sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
sim_scores = sim_scores[0:10]

candidate_idxs = [i[0] for i in sim_scores]
df.iloc[candidate_idxs]
# Out:
#                              id                               title  \
# 2793  ub1XiD9Imwg2SoD2qMNJ2kxg8                 admissionscounselor
# 314   xJ1oTn6KFvk5bGF3banD2YtO7              cassandraadministrator
# 2533  fO1vkH8GCKF9Tmq0OxEE8XnT6              cassandraadministrator
# 312   Ky1vAV6QpEB5HQb3sKxc0NED3                dataplatformengineer
# 2536  TA1WZF8wyaA9oCo1uaOe1Eit8  dataplatformengineeronlineretailer
# 1452  Fg1RUR7rdNG7ISp4qCQY1oei6                      devopsengineer
# 4771  Hp2umH6Nugw6vbp5tMut3UuP7       angular6developerseniormiddle
# 4148  HB2KNL5Mhuo8nOu1btsT6ovi3                        3dgeneralist
# 4946  Lv2bYq6HOjf8Qxd9koPj6aFW9                    3dartistanimator
# 4237  ar2RHU5UHLr9RfK4tTeB6hPl2          seniorprocurementassociate
#
#      employment_terms  job_type   deadline                     category  \
# 2793        permanent  fulltime 2020-05-01     administrativeofficework
# 314         permanent  fulltime 2020-02-12          softwaredevelopment
# 2533        permanent  fulltime 2020-04-15          softwaredevelopment
# 312         permanent  fulltime 2020-02-12          softwaredevelopment
# 2536        permanent  fulltime 2020-04-15          softwaredevelopment
# 1452        permanent  fulltime 2020-03-15          softwaredevelopment
# 4771        permanent  fulltime 2020-08-07          softwaredevelopment
# 4148        permanent  fulltime 2020-07-10        artdesignarchitecture
# 4946        permanent  fulltime 2020-08-15             webgraphicdesign
# 4237         contract  fulltime 2020-06-29  procurementlogisticscourier
#
#                                 required_qualifications  \
# 2793  knowledge undergraduate degree one year of exp...
# 314   experience with cassandra administration famil...
# 2533  experience with cassandra administration famil...
# 312   solid knowledge and skills in programming pyth...
# 2536  solid knowledge and skills in programming pyth...
# 1452  2 years of devops experience experience with a...
# 4771  nbsp at least 2 years nbsp experience with ang...
# 4148  proven experience as animator nbsp degree in c...
# 4946  must have a degree in fine arts animation or e...
# 4237  standard minimum qualifications education nbsp...
#
#                                        responsibilities  \
# 2793  counseling 1 accurately and clearly communicat...
# 314   developing and supporting services that provid...
# 2533  developing and supporting services that provid...
# 312   developing and supporting services that provid...
# 2536  developing and supporting services that provid...
# 1452  deploying tomcat and react applications releas...
# 4771  employ the latest technologies frameworks and ...
# 4148  read scripts and storylines to understand anim...
# 4946                                                nan
# 4237  1 provide operational coordination and guidanc...
#
#                                             soft_skills  \
# 2793     [writtencommunicationskills, positiveattitude]
# 314     [problemsolving, teamwork, communicationskills]
# 2533    [problemsolving, teamwork, communicationskills]
# 312     [problemsolving, teamwork, communicationskills]
# 2536    [problemsolving, teamwork, communicationskills]
# 1452  [teamwork, fastlearningability, communications...
# 4771
# 4148              [creativity, continuouslearningdrive]
# 4946
# 4237
#
#                                           prof_skills               salary  \
# 2793                                                                   NaN
# 314                               [docker, cassandra]  Highly competitive.
# 2533                              [docker, cassandra]  Highly competitive.
# 312   [python, cassandra, databasepostgresql, golang]  Highly competitive.
# 2536  [python, cassandra, databasepostgresql, golang]  Highly competitive.
# 1452    [gitgithub, nginx, saas, docker, tomcat, aws]                  NaN
# 4771                                      [angularjs]                  NaN
# 4148                                                                   NaN
# 4946                [3dmodeling, 3dsmax, maya, unity]                  NaN
# 4237                                    [procurement]                  NaN
#
#      candidate_level                                               soup
# 2793      notdefined  admissionscounselor admissionscounselor admiss...
# 314              nan  cassandraadministrator cassandraadministrator ...
# 2533          senior  cassandraadministrator cassandraadministrator ...
# 312              nan  dataplatformengineer dataplatformengineer data...
# 2536          senior  dataplatformengineeronlineretailer dataplatfor...
# 1452      notdefined  devopsengineer devopsengineer devopsengineer d...
# 4771          senior  angular6developerseniormiddle angular6develope...
# 4148      notdefined  3dgeneralist 3dgeneralist 3dgeneralist 3dgener...
# 4946          junior  3dartistanimator 3dartistanimator 3dartistanim...
# 4237      notdefined  seniorprocurementassociate seniorprocurementas...

# %%
# df.loc[df['id'] == 'Bt7vbu3oBdF6fNH5SvIm3'].responsibilities
