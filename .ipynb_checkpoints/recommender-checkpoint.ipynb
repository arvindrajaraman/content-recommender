# %%
import pandas as pd
import numpy as np
import re

df = pd.read_csv('staff.am_data_2020.csv')

# %%
def clean_str(s, condense=False):
    if isinstance(s, str):
        s = re.sub('[^0-9a-zA-Z]+', ' ', s)
        if condense:
            s = ''.join(s.split())
        else:
            s = ' '.join(s.split())
        s = s.lower()
        return s
    return clean_str(str(s))

def condense_str(s):
    return clean_str(s, True)

def to_list(csl):
    if isinstance(csl, str):
        words = csl.split(',')
        return [condensed_str(word) for word in words]
    elif isinstance(csl, list):
        return csl
    return ''

# Clean strings
df['title'] = df['title'].apply(condense_str)
df['employment_terms'] = df['employment_terms'].apply(condense_str)
df['job_type'] = df['job_type'].apply(condense_str)
df['category'] = df['category'].apply(condense_str)
df['required_qualifications'] = df['required_qualifications'].apply(clean_str)
df['responsibilities'] = df['responsibilities'].apply(clean_str)
df['candidate_level'] = df['candidate_level'].apply(condense_str)

# Convert comma-separated lists into Python lists
df['soft_skills'] = df['soft_skills'].apply(to_list)
df['prof_skills'] = df['prof_skills'].apply(to_list)

# Convert to date
df['deadline'] = df['deadline'].apply(lambda x: pd.to_datetime(x, format='%Y-%m-%d', errors='ignore'))

# %%
df.head(10)
# Out:
#                           id                          title employment_terms  \
# 0      YB5jCG9jORj5PDq5DQOK3                salesconsultant        permanent
# 1      Bt7vbu3oBdF6fNH5SvIm3                 managerhostess        permanent
# 2      oH7bOT6HPYs4xnr7JOQL4            marketingspecialist        permanent
# 3      zK7cxx6TSIV4lLp9sFba8             projectcoordinator        permanent
# 4      yg7GdF9DMxQ0YuO0bcOZ6  networkandsystemadministrator        permanent
# 5  Hs1rHE1aFSn5awY0Nujv6hEW7                        sfasdfa        permanent
# 6  sw1WyC2deDc2Qsb9hZCS0Rbj6         iosandandroiddeveloper        permanent
# 7  hh1PkS3HjoI4KhT0XPCO8psb3                                       permanent
# 8  Zi1VzG4lDLH7qYH6wVsa5xnP3                          sdffe        permanent
# 9  FO1lSO5ZBtg3wdA3OnZQ3UUJ7            digitalproductowner        permanent
#
#    job_type   deadline                  category  \
# 0  fulltime 2020-04-09    salesservicemanagement
# 1  fulltime 2020-08-26  tourismhospitalityhoreca
# 2  fulltime 2020-08-31      marketingadvertising
# 3  fulltime 2020-08-31  productprojectmanagement
# 4  fulltime 2020-09-06                   otherit
# 5  fulltime 2020-08-26       softwaredevelopment
# 6  fulltime 2020-07-31       softwaredevelopment
# 7  fulltime 2020-08-28     networkadministration
# 8  fulltime 2020-08-18   qualityassurancecontrol
# 9  fulltime 2020-02-10                   otherit
#
#                              required_qualifications  \
# 0                                                nan
# 1  female higher education in linguistics economi...
# 2                                                nan
# 3                                                nan
# 4  higher technical nbsp education at least 2 yea...
# 5                                                nan
# 6  experience in developing native ios app s avai...
# 7  proven experience as a system administrator ne...
# 8                                                nan
# 9  bachelor rsquo s degree in computer science bu...
#
#                                     responsibilities  \
# 0                                                nan
# 1  manage the daily operations ensure that all st...
# 2                                                nan
# 3                                                nan
# 4  configures and maintains microsoft active dire...
# 5                                                nan
# 6                                                nan
# 7  manage network servers and technology tools se...
# 8                                                nan
# 9  take the lead of a scrum team as a technical p...
#
#                                          soft_skills  \
# 0  [positiveattitude, customerserviceoriented, fl...
# 1
# 2
# 3
# 4  [abilitytoworkindependently, problemsolving, t...
# 5                                   [artisticskills]
# 6
# 7    [teamwork, senseofresponsibility, enterprising]
# 8
# 9      [analyticalskills, teamwork, productoriented]
#
#                               prof_skills salary candidate_level
# 0                [salesserviceexperience]    NaN          junior
# 1              [english, russianlanguage]    NaN        midlevel
# 2                            [initiative]    NaN          senior
# 3                              [b2bsales]    NaN          senior
# 4       [linuxos, tcpip, activedirectory]    NaN        midlevel
# 5                                            NaN          junior
# 6  [androidndk, iossdk, java, androidsdk]    NaN      notdefined
# 7                                            NaN          senior
# 8                      [phpzendframework]    NaN          junior
# 9                                            NaN      notdefined

# %%
def rep(s, t=1):
    return (s + ' ') * t

def create_soup(x):
    classes = rep(x['title']) + rep(x['employment_terms'], 1) + rep(x['job_type'], 1) + rep(x['category']) + rep(x['candidate_level'])
    description = x['required_qualifications'] + ' ' + x['responsibilities'] + ' ' + ' '.join(x['soft_skills']) + ' ' + ' '.join(x['prof_skills'])
    return classes + description

df['soup'] = df.apply(create_soup, axis=1)

df.iloc[0]['soup']
# Out:
# 'salesconsultant permanent fulltime salesservicemanagement junior nan nan positiveattitude customerserviceoriented flexible detailoriented presentationskills teamwork salesserviceexperience'

# %%
# from sklearn.feature_extraction.text import CountVectorizer

# count = CountVectorizer(stop_words='english')
# count_mat = count.fit_transform(df['soup'])

# count_mat.shape

# %%
# count2 = CountVectorizer(vocabulary=count.vocabulary_.keys())
# count2_mat = count2.fit_transform([test_job['soup']])

# count2_mat.shape

# %%
# from sklearn.metrics.pairwise import cosine_similarity

# cosine_sim = cosine_similarity(count2_mat, count_mat)
# df = df.reset_index(drop=True)
# indices = pd.Series(df.index, index=df['id'])

# cosine_sim.shape

# %%
# sim_scores = list(enumerate(np.squeeze(np.asarray(cosine_sim))))
# sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
# sim_scores = sim_scores[0:10]

# candidate_idxs = [i[0] for i in sim_scores]
# df.iloc[candidate_idxs]

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df['soup'])
count_matrix.shape
# Out:
# (6422, 13630)

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

df = df.reset_index()
indices = pd.Series(df.index, index=df['id'])

def get_recommendations(id, cosine_sim=cosine_sim2):
    idx = indices[id]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    job_indices = [i[0] for i in sim_scores]
    return df.iloc[job_indices]

get_recommendations('YB5jCG9jORj5PDq5DQOK3', cosine_sim2)
# Out:
#       index                         id  \
# 751     751  NT1pkG6GhZj9Vdq9BWnJ2LSL6
# 1050   1050  sG1WXX7heiT3jGO1FfbJ3ZDV8
# 1834   1834  Jo1PWW8lRRg1CCI5BrpW7Kug7
# 2070   2070  cR1Alw8sRrf4DFQ1bCRr1bTI5
# 2309   2309  If1jzW8UqFd6OXD6KkAl5GWg1
# 3918   3918  FI2eWQ5TnYc4iLQ4QgHT9QLe5
# 4631   4631  Ma2KjS6XrYA4IIi7uYFl8DNl3
# 5486   5486  Nw2gyW7cDGC6wqB3pLwA1yph7
# 4277   4277  SH2tjh6NGqz0cSd1QqnJ0lTi5
# 1105   1105  TI1Ozz7zItS3vPK7JKrU0HdQ5
#
#                                         title employment_terms  job_type  \
# 751                                                  permanent  fulltime
# 1050                                                 permanent  fulltime
# 1834                                                 permanent  fulltime
# 2070  idealsystemservicemanagerofijevanbranch        permanent  fulltime
# 2309                                                 permanent  fulltime
# 3918  idealsystemservicemanagerofijevanbranch        permanent  fulltime
# 4631   idealsystemservicemanagerofkapanbranch        permanent  fulltime
# 5486   idealsystemservicemanagerofkapanbranch        permanent  fulltime
# 4277     servicemanageridealsystemmasisbranch        permanent  fulltime
# 1105      salesandservicespecialistnightshift        permanent  fulltime
#
#        deadline                category required_qualifications  \
# 751  2020-01-31  salesservicemanagement                     nan
# 1050 2020-02-17  salesservicemanagement                     nan
# 1834 2020-03-08  salesservicemanagement                     nan
# 2070 2020-04-02  salesservicemanagement                     nan
# 2309 2020-03-23  salesservicemanagement                     nan
# 3918 2020-07-01  salesservicemanagement                     nan
# 4631 2020-08-01  salesservicemanagement                     nan
# 5486 2020-09-03  salesservicemanagement                     nan
# 4277 2020-07-17  salesservicemanagement                     nan
# 1105 2020-02-29  salesservicemanagement                     nan
#
#      responsibilities                                        soft_skills  \
# 751               nan  [positiveattitude, timemanagement, customerser...
# 1050              nan  [positiveattitude, timemanagement, customerser...
# 1834              nan  [positiveattitude, timemanagement, customerser...
# 2070              nan  [customerserviceoriented, flexible, detailorie...
# 2309              nan  [positiveattitude, timemanagement, customerser...
# 3918              nan  [customerserviceoriented, flexible, detailorie...
# 4631              nan  [customerserviceoriented, flexible, detailorie...
# 5486              nan  [customerserviceoriented, flexible, detailorie...
# 4277              nan  [customerserviceoriented, flexible, detailorie...
# 1105              nan                    [teamwork, communicationskills]
#
#                    prof_skills salary candidate_level  \
# 751                               NaN        midlevel
# 1050                              NaN        midlevel
# 1834                              NaN        midlevel
# 2070                              NaN        midlevel
# 2309                              NaN        midlevel
# 3918                              NaN        midlevel
# 4631                              NaN        midlevel
# 5486                              NaN        midlevel
# 4277                [msoffice]    NaN        midlevel
# 1105  [salesserviceexperience]    NaN          junior
#
#                                                    soup
# 751    permanent fulltime salesservicemanagement mid...
# 1050   permanent fulltime salesservicemanagement mid...
# 1834   permanent fulltime salesservicemanagement mid...
# 2070  idealsystemservicemanagerofijevanbranch perman...
# 2309   permanent fulltime salesservicemanagement mid...
# 3918  idealsystemservicemanagerofijevanbranch perman...
# 4631  idealsystemservicemanagerofkapanbranch permane...
# 5486  idealsystemservicemanagerofkapanbranch permane...
# 4277  servicemanageridealsystemmasisbranch permanent...
# 1105  salesandservicespecialistnightshift permanent ...

# %%
# Out:
#    index                     id            title employment_terms  job_type  \
# 0      0  YB5jCG9jORj5PDq5DQOK3  salesconsultant        permanent  fulltime
#
#     deadline                category required_qualifications responsibilities  \
# 0 2020-04-09  salesservicemanagement                     nan              nan
#
#                                          soft_skills  \
# 0  [positiveattitude, customerserviceoriented, fl...
#
#                 prof_skills salary candidate_level  \
# 0  [salesserviceexperience]    NaN          junior
#
#                                                 soup
# 0  salesconsultant permanent fulltime salesservic...
